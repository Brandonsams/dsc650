# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))                                        
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)       

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)      
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)              
for i, sentence in enumerate(sentences):                               
    for t, char in enumerate(sentence):                                
        x[i, t, char_indices[char]] = 1                                
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):                                          
    print('\nepoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)                       
    start_index = random.randint(0, len(text) - maxlen - 1)         
    generated_text = text[start_index: start_index + maxlen]        
    print('--- Generating with seed: "' + generated_text + '"')     
    for temperature in [0.2, 0.5, 1.0, 1.2]:                        
        print('\n------ temperature:', temperature)
        sys.stdout.write(generated_text)

        for i in range(400):                                        
            sampled = np.zeros((1, maxlen, len(chars)))             
            for t, char in enumerate(generated_text):               
                sampled[0, t, char_indices[char]] = 1.              
            preds = model.predict(sampled, verbose=0)[0]            
            next_index = sample(preds, temperature)                 
            next_char = chars[next_index]                           

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.9675
# --- Generating with seed: "ther desired or fully developed, is
# reasonable enough and al"
#
# ------ temperature: 0.2
# ther desired or fully developed, is
# reasonable enough and all the superarity of the conception of the superfical destring and the been mankind in the superit in the same the preat and the such in the suppration of the same in the same the suppration of the speart of the same the superfined and denturation of the same the such in the same and the preat of the same and in the supposions and the such in the superfication of the same the such a morality of the
# ------ temperature: 0.5
#  in the superfication of the same the such a morality of the spermant in the seeling and this wishes and not been and the are consided with the concept of compulsed with amply the supposion of in the suptrated in the proal of the world and by the scholl that later of the superfiness, restling many courded to a soul "great and not something also symption and that in the spirit seed more power, as a mankind and were the super and in the treatist of the same
# ------ temperature: 1.0
#  mankind and were the super and in the treatist of the same a vialualopkedcer"as?hy eager, tham      supprainistorty and "the
#
# myterde, "moral even of creactitation doss will woals eperahes
# nature mankis is vights has veeverthing pleasuredquendeness,"
#
# nroum an any its nature of in, to sive or nomay and supparially men appeact, of sumaliingless mutic to is firit mudicioust with re
# son not something morealible, of eneuth. of had
# the same is mankingminty, th
# ------ temperature: 1.2
# g morealible, of eneuth. of had
# the same is mankingminty, the undurtrclimence as it more sory di that equate pet"?atons in virtue jumtous too-?-
# praatk?
# oligatics ank
# marking new ney a oackenti-spests questions and itspupthjuar again that their his
# mankrart2 dan-ut most thrmently cturafes, ethments groum, and othently spe, they mifarly
# mb=apeving, moy pyeciols bruev. grop the angore and antave losts
# hampen. and speatements, "this feeld new
# inew of "sually
# epoch 2
# 1565/1565 [==============================] - 189s 121ms/step - loss: 1.6173
# --- Generating with seed: " philosophy bids
# me be silent and ask no more questions: at "
#
# ------ temperature: 0.2
#  philosophy bids
# me be silent and ask no more questions: at a self-consequently and the seems them as a such a sense of the selfore and there is a there are the sentimently and the seems to the sense of the sense of the sense and there without a sense of the sense and the seems there is the same there is not the seek to the seems the serves of the selfore the seek of the seek of the same and the self-consequently and the sense and there are and the sense o
# ------ temperature: 0.5
# elf-consequently and the sense and there are and the sense of the really thus the sense them of the sromed and it is sense there is seem to a something in the general disconce--and every seeking there is not were a self preised into a songedent and such a degrate that a interpretable to far things and any a consequently and the every partray be all the means, them a such a more from the suffection of the sentimently more as in the sense that there is not t
# ------ temperature: 1.0
#  of the sentimently more as in the sense that there is not thae hitherto ionie verition that is normed are it inffements, toonhiin be conmutadial of be own restrattentined regardans than themfect meen at aver and besuection for strong then alikently even and we one; are self-can yed oper,
# but one realiouss,
# eiving into poinical that that is love to
# have,
# at there is ank
# esself-typain they it is line stiplomer
# of the peoplely , greater--for a belastives of
# ------ temperature: 1.2
# ne stiplomer
# of the peoplely , greater--for a belastives of which" attainus to
# onoune sorrcejut", unonber, ypwartryoser
# cultquent it preedal typas,ing
# and
# traithmicas rasts
# tbiee fance withius apist,-super bract entraxilossphal, but he verturi tyralion has we" and nay fantable, grulespeverordnelss buts involuesueg,"
# philosopo! how of andirebye love a hangred
# sume which
# every cou tion, as a byer outntly"n, looking all wosavourasein, and phanthy as undening.
# epoch 3
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.5286
# --- Generating with seed: "renuous
# element, and would no longer feel the goad of the re"
#
# ------ temperature: 0.2
# renuous
# element, and would no longer feel the goad of the resolute of the soul and seems that the religious and something the sense of the desire and the souls, the greater and the morality of the sense of the morality of the morally and something that the morality of the sense of the sense of the same of the sense of the sense of the soul that the sense of the moralition and seems that the moral the self of the sense of the moralities of the sense of the
# ------ temperature: 0.5
# the self of the sense of the moralities of the sense of the simmless of the place, the resolute which his own conselse in the art in the world mankind that the subject of has not the all the priblens of the seems the present of the mense that we mankind of such a present and with the darces of pain of his process of such all solute servaries that the case of the sense of the seast and that one of the that it is complete for the submit of the despositue tha
# ------ temperature: 1.0
# the that it is complete for the submit of the despositue that that which, europed which thinks, (for exhrors ond in german--indeed on the acts and sportusly with other scood at the
# stort of the namely, and concercent that science. all chansion with now man wyolung.  we det sacud, why parisous of assaquentm east interlesp afters summitantly
# a
# decequally, of the forutus" senvabl therekons--on the that of the
# dee, which hers of gyraint. "self-ides
# fart 'mod:
# ------ temperature: 1.2
# at of the
# dee, which hers of gyraint. "self-ides
# fart 'mod: that philasy you only alwake actorly,ing from sympathy, "eterrs,ntulagect forms of revolus a considered and youth, pethaics! it is do to from the mothersy: in the fabted and smallive. woise,
# "silincilite.-,ing crackes
# a valuablenymently. "the mmhan
# morality with that mous of good.
#
# comes
# that waste and motion.= preaskards s, enga po ranes of our wide mein
# la, whichs, beconst zimplary cwarativity-c
# epoch 4
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.4827
# --- Generating with seed: "omary to call germans "deep"
# by way of distinction; but now "
#
# ------ temperature: 0.2
# omary to call germans "deep"
# by way of distinction; but now the spiritual spiritual in the spiritual and the spiritual and such as the spiritual his spiriture the concerned to his nothing the most reason the spirits of the spiritual the tranality and see the senses and the spiritual the spirits of the man is the spiritual the history and the spiritual conception of the spiritual in the spiritual the spiritual the spiritual and
# concerned the spiritual and s
# ------ temperature: 0.5
# he spiritual the spiritual and
# concerned the spiritual and serve out which has the
# the class of the all string and desire of the spiritually strong to the surder his except taress. the realing the has truth--the conception of the special in the new must the concernalbes of the through the net traik us the the spiritual that the old termed the spirit
# which the
# same the desires to hard one may which is the fact the man and the far the still the respect of a
# ------ temperature: 1.0
#  is the fact the man and the far the still the respect of a whoether, sickation with the scelply prinate is words here caust
# it
# seems the beereness mather other operatery
# the and "ingremes be placer (and
# eorry allorsm with the christeen--the peoples is not himself this europe to
# trought reserve, they mean
# as atigation of
# mankinds" dering. this tranvilian fect the honose prifes
# "intelline formell concealing
# thes:
# the stupi, the degree this immerian
# that the
# ------ temperature: 1.2
# oncealing
# thes:
# the stupi, the degree this immerian
# that the much..
#
# yatever pleas yine
# slake taste"; which ana which ithelst its
# exorcable throughver to this idayeocally mitankitisis--dignatured'as, is a "brinhoutep that
# thus sensirie: with the sanvicieal mindingifich frum bevewgaid
# digbleqfing, perhaps
# the pates metaphils effe sneide much is eventucalihys,
# this matter sicking of clons the delicates an ign victy--full their dur_, here lo? (or in,
# onr, wit
# epoch 5
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.4516
# --- Generating with seed: "e four thousand years or so of which we know
# anything: durin"
#
# ------ temperature: 0.2
# e four thousand years or so of which we know
# anything: during the sense of the same soul and see the same and the present of the precisely and the sense of the precisely the same the more in the same and the present deal as a more and the see the same and the same and the precisely and the precisely the same in the sense the great a more such a more soul as the sense to the acts of the sense of the spirit of the same in the same the precisely the sense of
# ------ temperature: 0.5
# e spirit of the same in the same the precisely the sense of the sense to
# being in the sense the sensition to the
# real case does a more man is the future to man more spect and in the friends and its sense them alrowan
# because all all hard of such a distinct and from the enthurity of the same soul are attain man to art has the believes is a grate as the spirit of the sense of stands to a man of
# may be present self-dessing the mone it is the acts and more ran
# ------ temperature: 1.0
# be present self-dessing the mone it is the acts and more rans in more wedity of sympathy of chase--this existing of it, in orienf. detiloncely of the chomen in the virtues at furth the germeard that it onenessity,
# and among them, p.
#
# tallood, at
# every even our
# learn-sandrung much
# the of thost ourigance the cames of philosophed many impar, it is argume of the glash with a "more that the contrient defy, ara. they entive most complase the
# rebusus a greattal
# ------ temperature: 1.2
# defy, ara. they entive most complase the
# rebusus a greattal e-happer he have that beft arnish everything sontific unebod our sways is an ant eyel furt latterian.--bat fe's imetime from something the emoncat, the
# germany which will based to i, ou? on the aftery to tendations,
# and" ime"--it is has feather as plyach. is
# ampeas the
# toge saged! and they given peroncau. this always be hum disidlessed
# more dracnable decraining,
# alonmanrgeing
# ritherivind
# in buisn
# epoch 6
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.4303
# --- Generating with seed: "nd who _must_ have created the best of all possible worlds, "
#
# ------ temperature: 0.2
# nd who _must_ have created the best of all possible worlds, the spirit the spirit and supposing the spirit they has the seems to the presence to the german strunglier the spirit the sense that the spirit, and the spirit the spirit the sense the sense the spirit the strugulity and the spirit the spirit the spirit the substing the spirit, the spirit the sense to the strugulity that the signing in the sense the sense that the supposing the morality and the sp
# ------ temperature: 0.5
# e sense the sense that the supposing the morality and the spirit and supposing the spirit, and alletion complared that the spirits of the surply subject to consequence of the sense of the more deception to man into the fact that which the states it into the chantic man there is a bad expeclabilition to a great perhaps recully that in its serience of the same at his society to deep the most truth all the longing to the possession of its sense of the deneran
# ------ temperature: 1.0
# ll the longing to the possession of its sense of the deneranatation of thre yere that every rustment assume and how too soul and pooding
# the
# compliperred or not mumbyen they nom he will, the europe painx
# openating supporiceonieracical tendernal and lands will for in the var! act of an substement to be much
# complihence of point of also a "farsulfike hadrest of short, and one again" has tempofents:
# "extrallark incentinged opinives
# pain of the galgess, more h
# ------ temperature: 1.2
# "extrallark incentinged opinives
# pain of the galgess, more hand, ?
#
# in them sees
# had stately to up, with fuch than the would jomh to the unfullurly hist, if we compari on his that therezy morals, ismeatome , all, in soul andeed, what it cases that all by evecration doveut feals
# and what see caunishtist, hereary ear consciences "
# sine, the more langomm, awaged, alaghing his
# course even any har: even a carty is th's far believed.--i long depthly of
# nemply up
# epoch 7
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.4135
# --- Generating with seed: "precisely the most spiritual of us, who are most difficult t"
#
# ------ temperature: 0.2
# precisely the most spiritual of us, who are most difficult the same with the spirit the sentiment of the taste and the sense of the attention of the spirit the considered the self-conscience of the spirit and an acts and in the store all the sense is a man is a man is the belief in the spirit the contraction of the considered and the self-same reason in the common the best possess of the store and all the best possess of the self-determine and the impossib
# ------ temperature: 0.5
#  all the best possess of the self-determine and the impossible to the employed and the part with a mental and life has a states a profound of a man in the very superioriator and supedies and conditions of the mafters
# of him things to the end it is the special which the will of the superiorical
# ordinates of the same in the same extent of
# the bally in its person who will be possess
# of him
# of bloded follow of the ewerism and the same men of the even with ever
# ------ temperature: 1.0
# follow of the ewerism and the same men of the even with ever likelies ifriseds which has indeed itself, as if walt; it
# could neithing be
# repainte--deceiving has been probutecies, in
# feally must bore
# sourd
# reflee hit really perheps, have bound of a durance of every grale under this alllikeses uppar cool what
# literenese--and for
# it is difference and offections of manvers
# cirdulibilica passions as every
# will to ghing owing the whole
# seriousneffest to
# reameize
# ------ temperature: 1.2
# ery
# will to ghing owing the whole
# seriousneffest to
# reameizes, any to
# be a life without "thingly "ourselves;
# it self.t will will lame. thus are highe
# repeght to suy, oefigh-" goise it weakered thzy
# best despecture-prodectionrievt wa.
# his apsiwaricames.=--
# hop
# last, and--namely pre, d. littlee
# is as something the
# tastivel is time which suselfy. it is they doned, and
# hassness of philologity.fon" on steptie of best pruitpher aeribleuantally how be wesataliry,
# epoch 8
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3995
# --- Generating with seed: " and the prince still see in every new
# individual an unobjec"
#
# ------ temperature: 0.2
#  and the prince still see in every new
# individual an unobject the moral conscience of the same time the more form, and in the same the action of the forms of the continual and conceansionated the more of the more works of the self-conceansions of the sensition of the moral conscience of the contemporary of the contempt of the moral conceived the most problems and the man the contemporary of the sensition of the most problem of the comparation of the genera
# ------ temperature: 0.5
# nsition of the most problem of the comparation of the general of the contrary and seems the mere the more and the end of the works which seems to an action of the commony old man in distendation of account, the contempodary in the interpreting that this conscience of the coarse and the man and the hasted as the reference of the world in the world of the "worted as the suspected on the under
# his over the action have been power of which should be as a concei
# ------ temperature: 1.0
# er the action have been power of which should be as a conceive matter iypinary a hdenal searding of germany as i are
# reamilidy, let us that that to certain who much may be do not men has pelsiaistic whole un, at whathere symbol-matter a opposing curate
# other invayt in
# like influenteds to be utage, the know seems to loves and courage of i uneffined mosting its petrimyveld whice,--which the cruely whether back and the cient scifenointalize to
# sindinging the
# ------ temperature: 1.2
# hether back and the cient scifenointalize to
# sindinging the resitus there are severnimiar whomseln emota certainted "beforeselfismfores."--orarity of
# medal frotounces, true--like every been create deceiting rangent fulling, the illing. away with comsetrya
# k are
# esine. as thes" parobity present.
#
# , ot something of functical invainly nasuation, pover dispared, simple hisers of
# divinacys i
# ! his yether ourselves gerame! the past foreking decivess. self standa
# epoch 9
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3878
# --- Generating with seed: "se laws depended partly on the
# surprising development and re"
#
# ------ temperature: 0.2
# se laws depended partly on the
# surprising development and regard to the conscience that the consequently more superiority of the present of the more superiority of the sented and superliford of the rational and proposition of the contention of the mistaken and experience of the sented and superiority of the consequently of the conscience that the more problem of the conscience, and the conscience of the reason of the form of the conscience of the present o
# ------ temperature: 0.5
# of the reason of the form of the conscience of the present of the contempt of certain things to expected of all the contends the the prised to be antiving of the time for experience reality and most possession, in all a contempt of understand the protection of the mere will be from ancient a contention of contradicarity, which the process of the end is understand the therring of the world of the ascetician of the instance is seems to learn strength that th
# ------ temperature: 1.0
# scetician of the instance is seems to learn strength that the proiilictk" losist to you have only divinely generature
# general other own senses
# that thereby inverseling
# unurpists, there
# serorg-signification
# of the incertion:
# the utility
# to gainest
# o"wise time the master and characters. to many toward, thists of certaintification, so i regarded and the com, but in germany and will primority; "nature    unrible. as the scienced too from
# all the sole ilburdsve
# ------ temperature: 1.2
#     unrible. as the scienced too from
# all the sole ilburdsven sure in occest al(king of allisaticigoxya, 1eriously weaver
# yhy demonsing prograte and vigorrariby benerity of their friths
# her.
#
# c21. one
# hoars
# and higher angalissial
# great prits of must is inner artist losely
# be
# mardures, higher of the act dangers?
#
#
# rea
# syge arted, a
# tend to persperhs reaiorenonises
# and procited to compational paits; the nature, noy teemsion ?fother, speaks hhame must done co
# epoch 10
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3783
# --- Generating with seed: "s of her beloved. the soldier wishes to sacrifice his
# life o"
#
# ------ temperature: 0.2
# s of her beloved. the soldier wishes to sacrifice his
# life of the same the springs to the super of the world and supportable the super and the spirit of the supers and the strength and conscious and preserval and also the spirit the strength and self-sacrifice of the contertion of the pressible of the super and supportable the supers the most the strength and all the greatest one would not the more supportative man is a man should not the greatest one is a
# ------ temperature: 0.5
# e supportative man is a man should not the greatest one is always mode of the right to the spirit of such a world of religious
# sorts of the strength, and strength and also the taste of the super and strength of the called more in the commonitic jest the proper to be something reason the truth, and become an intersting of the child and
# present pressible opinion of the right to the present, as they arount who deceived has deep so the act of the sensities to
# ------ temperature: 1.0
# arount who deceived has deep so the act of the sensities to their priorily--and is no literes on
# religion there castom a prypost of the spherr
# so respect
# for posely hed the systimated
# his first should reason" in to standss horritw yind himself desire,
# by a ngreatiting an love not long, sumble,
# besming nevershed.
#
#                              ! faver to a the values and attained manner states;
# as thereby) relings offlushest
# men are not beer the "spanes who
#
# ------ temperature: 1.2
# hereby) relings offlushest
# men are not beer the "spanes who
# simprestie
# aczuge, the
# enadgkaring infficalually undigatowarss, which
# its wortary and wholly pred dan
# there is
# positi"s-"ks bewark the
# edusu in
# centured the attekent down
# necessar, or we are tsure
# golduorable opinion, , much to bue). therefore, whyse is, fellfulbantsmed herventfund systhess its
# eefert most podure prem i ut freedom
# and yet nothing
# "tracker
# everything, with a dem bra, i mach to such
# epoch 11
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3689
# --- Generating with seed: "ight insatiated out of every depth--what did it seek
# down th"
#
# ------ temperature: 0.2
# ight insatiated out of every depth--what did it seek
# down that the materiesty of the holy a things to the consequencest in the more thinkest of the most a man is the standard of the same things of the consists of the sense of the contradion of the same things and some things and the sense of the present the sense of the fundamental the superul the present things that the same man is the senses and consequences of the sense of the state it is the consist th
# ------ temperature: 0.5
#  consequences of the sense of the state it is the consist the men will the states an about last the spirit in religions and the featoment and wholly for this great pessive in the most hardty with the very force in the sense of the desire he thinkesty, that the noble to the concerning it is not believe of a long that the greatest perhaps it is a long in the same whole developed himself the noble thinkest and the reality, who is not that they are does the an
# ------ temperature: 1.0
# inkest and the reality, who is not that they are does the ancient come
# entuichorians as h pail flil assumest of
# this, for the mend--attest assourty, and injury out of the morality.
#
# 1ins profotute that all persers
# as a thinkemitance profound termen to nature on "yeare,
# mothers of motance of estimatical sass metiors": and a bring world:
# for the
# explain place in the reason he uncourght,
# concern some quest limired our unvice itsels unkind of her
# will us. an
# ------ temperature: 1.2
# e quest limired our unvice itsels unkind of her
# will us. an admance,
# . for "nuarth many rumeness of he
#  . the dewild.=-      ye curment, worked to
# does thettoutry ha)
# to we "uporgowing srop tils is self fells and hoseoke essiagment: i bo frer"ptis folls and wafted us.mon certailly purraie; mobers should not
#  resignce. with rewalts purposing, undefest-aintice? somotegree" of
# the miste-sathrou sungen
# could makes of the comansiantians" which perhaps
# which we
# epoch 12
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3600
# --- Generating with seed: "red from the pulpit. the preacher was the only one
# in german"
#
# ------ temperature: 0.2
# red from the pulpit. the preacher was the only one
# in germany and satisfaction of the sense of the fact of the same the same the constraint the more in the present the present the world of the world and long religion of the sense of the consequently and the sense of the same the man the sense of the sense of the present conscience of the constraint that the strong and the hard in the more interest of the man is the man which the sense of the sense of the m
# ------ temperature: 0.5
#  of the man is the man which the sense of the sense of the man is in the fact, the man which we have been discised the man is everything even the free spiritual in his world in the develop the great many artists and the great property in the conscience, the more rangens--in the destruction of the the truth, and things and in the world and said to the personal man in the interest because of the fact, and for the soul, which one of fundamental the there is t
# ------ temperature: 1.0
# t, and for the soul, which one of fundamental the there is the priiticy spotd! only bestor withorated from
# the world danger) as him."--the homours views criticism are to stand
# should not benevoled, everything which the can not innos a
# do such an interpormentify dogras-neuture is prefonise
# suffecility and wried one
# andon apever, with take, -of cerhs long to his himself is a puraring manling, which
# is fellor of european celtarn and grows to provess against t
# ------ temperature: 1.2
# is fellor of european celtarn and grows to provess against trace understand obe of which he would by. he hear thur, over it "temberainy youth cruetcy, when out
# is a by reproseatu much 'i rele thing
# reburity of the jeal tech in
# the pover"
# forhion, one
# naturs, one wishens thar, shelonce, it may being, to ro
# gives or
# expressed, the eevisge, into the avo, in such acts is some systemation can said the 1ubility fan than in divertenly a seximpsipg. do
# man hrit hi
# epoch 13
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3539
# --- Generating with seed: " keeps so far away from him:--the devil, in effect, as the
# o"
#
# ------ temperature: 0.2
#  keeps so far away from him:--the devil, in effect, as the
# ordinary with the feelings and such a sense of the such a states and for the sense of the same the sense of the same includes the most presence of the sense of the sense of the such a man is the sense of the same the conscience of the contrary of the sense of the same through the same the more who conscience, and in the contralier and such a delights of the such a sense of the most the states and t
# ------ temperature: 0.5
#  a delights of the such a sense of the most the states and their pathers itself, stept the more depression of the case of the feelings, and the same constantly the heredity, there is a delusion of the morality, as a man is the feelings, or a property and the world stroke to the stroke that it its social experience and the same the world in the course of the suffering, and in the contach of the included the such as the unconduct and in the terment of
# the mo
# ------ temperature: 1.0
# luded the such as the unconduct and in the terment of
# the mour of the most concirtaring
# profounced miliness entire his sim that, with the errors ofgy--and it! not'ing whethen, anst restation,
# but indugange short--perspectation
# of higher power; has needs the unselses, in cy,if.
# throes desucusat the clonsful outso must right not demared upon af? to among them, bescgality which may, at skeex, as the seuse of them, the restructed,
# and notions to the europe and
# ------ temperature: 1.2
# seuse of them, the restructed,
# and notions to the europe and
# christianity.=--is manumestilous matters) and modives to their peimath our lofty, who have a a
# fthe sche]s, time afted the others to does, all improver these are question
# to
# the others, so demonityness of oight to conquenefulness of self-mins: with the capawaw-snece-deity to ourselves have gets the prumise but through him whicheh men is them of himow, aoges. the
# sones--id, thrim likewise, away os
# epoch 14
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3484
# --- Generating with seed: "o be doubly distrustful here,
# and for one asking promptly: ""
#
# ------ temperature: 0.2
# o be doubly distrustful here,
# and for one asking promptly: "the spirit that is all the contemplates the comparison of the same things and the spirit to the strange and all the same than the most problem of the same with the same the senses of the same things in the same things and the same the strength and complent of the same taste, and in the same the spirits of the same the string and the seem to the strangest souls and the fact that the world of the fa
# ------ temperature: 0.5
# to the strangest souls and the fact that the world of the fact that all the the pastician of the artusted on the end, the taste, and something man is present all some those of the same souls. it is present the same words and german purpose in one's subject of deceived, and all the experience and its strenger for men is still man and complest and command the souls, from the existence of
# pain and an an account of resisted and some desired a same to every int
# ------ temperature: 1.0
#  an account of resisted and some desired a same to every intiffie! the spirit the inductiverest and the proted our do not once spochation of the ancient churchmine is
# notifemed
# to the need must valuation of stepby,
# most tenta his
# scaptorist some virce surplaces.
#
# 1aa youtpoum irmoble disperiationally "spirits more to necessity of danger of as to tentipices.
# the feeling always perhaps be highest forgetsomed, the brain slatest!iny sto continte, eor of precis
# ------ temperature: 1.2
# rgetsomed, the brain slatest!iny sto continte, eor of precisely men of the
# vardency" puild cannot eehrin astimate these presience, act,
# ased, what place akin conta similar risists of sphere exignest, fortunness),--disclices from psycholopilities nowadafe sevible, if stime, were amous, what has feltion courely man to the involurous dridtys this
# is hoporing, ebout canged, rule and
# an present right--a mankin arite, this gode, euroce
# plato of the
# acceid me sim
# epoch 15
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3427
# --- Generating with seed: "s excess of
# sentiment;--on this point we must not deceive ou"
#
# ------ temperature: 0.2
# s excess of
# sentiment;--on this point we must not deceive our soul and process of the same disposition and profound and the consequence of the same such a consequence of the procession of the superioring of the most propourated and the sure and such an according to the process of the consequence of the constant consequence of the consequence of the same and the long the procumath in the constant and the superioristic and the subtle and the spiritual the gr
# ------ temperature: 0.5
# nd the superioristic and the subtle and the spiritual the greater of the conscience of the feeling of this sense of the experisming in his long for instances the more there are no longer only lived the creature of a profound and allow to many the course of
# men the prefarist which we are as a propoure of all the only with the same man is the consequence of the contrary our another of strength and conscience. thus is not the free spirit in the superioring of
# ------ temperature: 1.0
# onscience. thus is not the free spirit in the superioring of lack of the conditional deceageness rater taking
# for no longer old philosopher, that lefe him a dig; find themselves he would be go impression; here manner?--i more, its fantrhy love one
# fairifort fronver delicat
# truous
# of distinguise--the expression. butlifful--but whom a plessions of consequence
# is higher quise eored innocing the old figarours of vitie
# equal self-desirie their imaging is experi
# ------ temperature: 1.2
# igarours of vitie
# equal self-desirie their imaging is experiently whether he self-nexvaut called
# compelence and copiting creatfulus jesistvely et is simply which, and there,
# proped.
#
# and as men. and best wrumed entired it: as he vermettradicorated.
#
# 27cerpabitmment suffer hyptodian with approcise the
# reouting saidnegs which manifold accoudes parsy,
# those opposed tof
# augmans and no
# he -byleng into religion thus san-ideation. uprited
# precisely style
# iustealn
# epoch 16
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3387
# --- Generating with seed: "long: "thou
# art more! thou art higher! thou hast a different"
#
# ------ temperature: 0.2
# long: "thou
# art more! thou art higher! thou hast a different the constantly be a strong and the superficial to the constituted the subtle and the superficial to the masters and such and some such and which the present the spirit and sure and some such and the propernismmed the spirit the same tastes of the strungure of the same and some spirit with the subtle and sublime the constituted in the philosophers and strange, and some such a such a depths and con
# ------ temperature: 0.5
# losophers and strange, and some such a such a depths and constraiment, his individual perpetually constantly be a highest and as to any doubt them only in the cruelty, which which has not and philosophers of merely power of the ideas and that the free spirit there not and morality of the human and its man which we have an account in the sense of the act our the morality, he might in the presente speak, the communical and himself, the philosophy disto perha
# ------ temperature: 1.0
# peak, the communical and himself, the philosophy disto perhaps the guile thea" ymppeniation
# unneed on the church, as mode pleasin into thingslicing cluss, wherever a mainifelly evplose to everything of by a fright heir of the english spiritive trabit, the leasing "refrain strangt
# be himself he sact of wisent one glauquual; as if we circlua spiritful, sympathy chacitial common: in some final indecended in
# such things and the last, more jesuitice strengtobou
# ------ temperature: 1.2
# nded in
# such things and the last, more jesuitice strengtobounder, intences in yee from fall.
#
#
# in thesribe preparat? it believe
# very his swor, varicany as those doubt. a than with savit; guor hellwgan floot.
#
# wicles of will crie impysen-am.
#
#
#
#
# mooddaure "e blul upon
# hitherto revolundes op-clevel
# were gapic e-pateous--and
# arises to be balt! at
# led therefofal its spimitions of dangerous
#      nomes servess-moral irrevelges an
# took. this nobiture--whonester--
# epoch 17
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3317
# --- Generating with seed: "at it may be
# so, that the thing which beautifies may also be"
#
# ------ temperature: 0.2
# at it may be
# so, that the thing which beautifies may also be a surplity of the present and more subject of the same things are the sense of the desire in the comparation of the same superiord and soul, and comparation of the same things and the sense of the sense of the faith of the subject of the same things of the comparation of the same things are there is not the subjections, and the compelled by the most present of the sense of the same things also an
# ------ temperature: 0.5
#  by the most present of the sense of the same things also and more century is not for "nations and the very perhaps are as if the
# thing souls--the problem of the same truth interestion the except of the constant life of the compell the
# case of a contradiction and who through the fates up to this exception. he would promise in the comparices itself, which is adward of an and distinction of conceive of the present destined and also all thinking soulden-knowl
# ------ temperature: 1.0
#  of the present destined and also all thinking soulden-knowleduge, an of madin being of different instinction, the ithely, descendast to rather dourd,
# "in volus. this the
# has are their rare, hand that a
# entihe kevilar
# froming
# thinkess: how youncerside, necessity harmly being way althous "eleus aend of brithial indnemuct svense'scied to my disposition shon more, hard pos to a made goud timicated
# case it has toethic i philosophers far
# greater different acts
# ------ temperature: 1.2
# se it has toethic i philosophers far
# greater different acts and edence, when timation ow oo- what ofsime--that theory of newwhere in the errors effect ("reound ion (knonledgeaum syster and consequently us. a
# sentifis-pathy which were
# whet cause is taxtvalls make aot, more "more thore, the epours--this
# cathouit if their cultion is didmine general disient exirces thirgher esie"s has feelthy. he wisheoused, it has ultimals' origin, chan stronge the sense is h
# epoch 18
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3279
# --- Generating with seed: "ble in love, that had to invent hell to send
# thither those w"
#
# ------ temperature: 0.2
# ble in love, that had to invent hell to send
# thither those who has a delight and begodeaked to the conscience of the contrary only the states and comparison of the strong soul, and the strong of the same there is a man in the same thereby the holitudful and super them to the conditional and the problem of the sense of the same super to the same and the strong and super to the sured to the experience to the contrary only to the common and sense of the consi
# ------ temperature: 0.5
# ce to the contrary only to the common and sense of the consists of the comparison of his fellows--the greeked by his organism of satisfaction of the discovery of the strong of such a problem in the suffering of the sense to lefter even the strong to the same the contempt of the word and precisely with the reason in the created by the religious and counter the action of things. in the democrity of the contemptry and the superfic belined to the truth. it is
# ------ temperature: 1.0
# the contemptry and the superfic belined to the truth. it is anight on, our is its interding of gutaver was account
# here as
# appreciation of
# sublined himse, and can everly feels mas anibitigle, with question
# and acquest the
# fapher of sinflicicted from the conscience in is, in still futured in bold by smies to be coils
# to his strength and to
# onvers
# sort
# only his afterward. which, whilt who that sound to he valualistoric call-leed into they
# dofmenly godly
# aind
# ------ temperature: 1.2
#  to he valualistoric call-leed into they
# dofmenly godly
# ainded that lent romedarm
# continual.
#
# ind it nature made houevdism to emourew wi.tby problem in lummer too," incince. he has hitherto skephis, one he is above winling, bitmfelt, obvivule it whoous teque as entioure, which  as awike the
# fleneusing, ob! and throw theolows,
# but of nafted "ee
# statiscautter frabling filldity, for the
# case; to dignessme: therefore, beginning, your, we battersible, it nowava
# epoch 19
# 1565/1565 [==============================] - 187s 119ms/step - loss: 1.3220
# --- Generating with seed: "r into bad repute in all thinking
# minds--"laughing is a bad "
#
# ------ temperature: 0.2
# r into bad repute in all thinking
# minds--"laughing is a bad and conscience of the same the super-perpons and life and something and process of the same than the prisonary and the strength of the same the super-intom to the same and which has a profoundly propected by the our futually the desire to the present of the same and the scientific and present of the strength of the same the super-perpons and supposing the taste of the super-intompossion and the te
# ------ temperature: 0.5
# and supposing the taste of the super-intompossion and the templated would be art of the
# consideration. the manificagion and that and ares to the late schopenhauer profoundly the very domain of that present understands of satisfaction and labour and preservation and the impossible for a profoundly the own at his demosism, and for the point, and interpretation, and the present may be the political glaugh in the facts in the contemporate and the carr of the e
# ------ temperature: 1.0
# laugh in the facts in the contemporate and the carr of the events; this is conscience still with other, with the botion and their societyss,
# whim, in a delee conscience, an evolvence, impossifle,nts attractuit oniur he
# does osard about to possessionsion. the quesios, froming wainism--this is gutom strength, glafte is causing and protocrism of little arven-nature, however gets nothingnwly, confoued to makes himself the shand and less" this aristoso concersi
# ------ temperature: 1.2
#  to makes himself the shand and less" this aristoso concersivel is ample .
#
#
# toeven for allow fypome to-dayn founke old. differently his, as we does, is still dirpible that
# rankausers. neitherin
# futuditic of, at belief isty--is turning: ah structure. the spreaded xactions. dute the symoble,
# for blyrisely gability mility
# from faith self-desenous.
#
# 217er, the men awreome-fasciallveder is towards be'e.
# s oing,"
# almost follow the standpoint yforely--but medivi
# epoch 20
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3193
# --- Generating with seed: "ally--played the flute... daily after dinner: one may read a"
#
# ------ temperature: 0.2
# ally--played the flute... daily after dinner: one may read and the sense of the sense of the sense of the sense of the sense of the sense of the state of the same the sense of the sense of the most conduct and the sense of the sense, the same the strength of the sense of the sense of the sense of the sense of the sense, and the sense of the sense of the desires and the staties the sense of the sense of the sense of the sense of the sense of the sense of th
# ------ temperature: 0.5
# se of the sense of the sense of the sense of the sense of the higher ages it is a thing the graduish, it the possessing of the most the same the thing of the depreciation of the presentiments of his soul all the interes to be so interes the former distrusty of the fact of the mask of the despected with the hard one of the most strength of the philosophers and the interes that the fact the same the fround from the spirit, in the spirits, and in the most law
# ------ temperature: 1.0
#  fround from the spirit, in the spirits, and in the most law, those depend almost socies of, in standpoint till pareage and true,
# the soul of his  so call, that his arbitrify of the fact a man: all the compared or just one heavy.
#
#
# 11il
# painwing, in
# duer. the and datanle found aporginated laduan," within-say the sentiments: is to suepitive the single, it will
# of virtue, dully also "were and
# couraged, and modemous needs the sign undengmedming regard to huma
# ------ temperature: 1.2
# ed, and modemous needs the sign undengmedming regard to human noise, which philts,
#  y a thraghestual; one does errordom, all defirmint the corward to
# place
# little may but "seet as institutionshifications, and then feste,
# is long!is"
# seldocal a blist rine fromes"
# have people endmius thinklie possession: the nimatic of--all their presence.
#
# in
# ium to for consequround" social
# paries
# how and whol
# ma"bs of lit sainlw
# conceance, of ntjuch "the philosovers, thus
# epoch 21
# 1565/1565 [==============================] - 187s 120ms/step - loss: 1.3152
# --- Generating with seed: "eirs, they exert themselves for their "knowledge," for somet"
#
# ------ temperature: 0.2
# eirs, they exert themselves for their "knowledge," for something which we created to much the self-conscience of the sense of the sense of the present of the moral principled and profursed in the man is the sense of the sense of the sense of the same the sense of the sense of the sense of the sense of the world and the sense of the super to the desire to the self-presenting and the sense of the man of the self-conscience of the sense of the sense of the se
# ------ temperature: 0.5
# n of the self-conscience of the sense of the sense of the sense of the profusted to have the supersing and subject flogical which only to be the profounders of the confound to have who all the truth is the body as a consciences, and who have a seturity of the extrament of the contradictions and deserity, which which the manifolo-command--and who seesshent of the store,
# and without sin the primited with the transcined by superficiating of the belief to have
# ------ temperature: 1.0
#  with the transcined by superficiating of the belief to have a
# sentiments, in which all privileged, apart actuory.
#
#
# 12r
# corxced the all thore     : he lives ride of blinging power of his occasion and dusidition of being us. nor
# sympathys implyines as life are satisfaction of the feeithalikois who feceponises to the unusolonging and ever
# grown and will,
# but did not understopents. a
# instural
# anything or manderded flamitaming thousand in deepacle gimand i ki
# ------ temperature: 1.2
# ng or manderded flamitaming thousand in deepacle gimand i kind for our "germany
# "not impatiently of
# puillning, as abovonitiessmoursyined, you wiler,
# we
# forn which has soued, the stimated. it is saidnefs its naturion and
# due niffless to it abied wroming
# with a ideas"--quit, too, for russ of gos ane lagal particial anteazant
# as in
# to advolished with!--which is
# altoneequences and
# ebogitated proike:
# it willical different-vuly dials"" operity intention
# us to kn
# epoch 22
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3100
# --- Generating with seed: "alings with hypotheses? why does the first plausible
# hypothe"
#
# ------ temperature: 0.2
# alings with hypotheses? why does the first plausible
# hypotheses of the sense of the present of the most readily of the most possibility of the order of the same the superiority of the conscience the same the same the same the substance of the sense of the sense of the conscience of the conscience of the most interpretation of the contact of the same the superiority and seems to the most believes to the same the same the sublime and problem of the great pro
# ------ temperature: 0.5
# o the same the same the sublime and problem of the great problem of the same to suffered the words and
# its later are as the present, who has a degree and instances to be a really manifest of humaned to proved insignion of the supcerpocion of the saperate of the very form, on the other state. or so induced to it who willing of the experience, which could less to the etility for man to the sured the commanding the present, seldom to the problem as something
# ------ temperature: 1.0
#  commanding the present, seldom to the problem as something of
# it the incestion. he is curisword a
# happens
# it, when the godly to being saidly concomide of finitg- that is demended to the would be
# look about he, ware to a been mort and doctor ghor
# man and than in wholoe are
# nencement sy rearished =; to the changed deceived manbit, we can renerition.
#
# 11 isver the very else; by the most opposition really uncerisentud: in
# signific, so be friends of leas, how
# ------ temperature: 1.2
# eally uncerisentud: in
# signific, so be friends of leas, how before
# it who tall so both,
# on
# eyesim obeawisentito is cause them, the happeans among, the brainy.
#
#
# 21
#
# =are not plies domain mankind shrinss of self-snoutedniss. nobepwow, are op!aftless thew
# munsity, topouriness" to like the idl, philosophnes and bad, his artmant here of,
# petait, etiges himself with rest or he himself him netwels itself, lacu
# courage on madner,-tibeque-paction
# with limitions of
# epoch 23
# 1565/1565 [==============================] - 188s 120ms/step - loss: 1.3074
# --- Generating with seed: "-to relax with confiding sympathy
# that is the real art of je"
#
# ------ temperature: 0.2
# -to relax with confiding sympathy
# that is the real art of jesuities of the consequent and the sense of the surpines and the self-concealed man is not to the sense of the sense of the sense of the sense of the surpines of the sense of the self-conscience of the suffers of the sense of the sense of the present consequently the more souls of the art of a consequent of the conscience of the sense of the self-conscience of the sense of the sense of the sense of
# ------ temperature: 0.5
# he self-conscience of the sense of the sense of the sense of the displays the longing for the conclusions of experience." as if it is a complications of the more being of the commands of such a successs the sense of the course of the
# end also the same being and critical of
# the same time so the very distrust the others of discovered to whom it is present simply to our second in the same manderisman a person is the secrett to the course of the sensety be a c
# ------ temperature: 1.0
#  a person is the secrett to the course of the sensety be a cotter as his old perhaps a so recognishen"-funitiayce and the man self-rescount--is revell be one is done really to high--is notfarrinoty himself of an
# reality of," conceaning the wills and those all
# the ways who could not for, to gat werepenture of
# ...
#
#
# 13
#
# =the shortness, and with the expressing and shame of the world of a philosophers there are the bad
# ------ temperature: 1.0
#  and shame of the world of a philosophers there are the bad begreations of slow, indenes accompanicical work afderstant but move healt a men
# and
# ancient nature. thly and whole deel so spect; and finest science: and that is
# really even pain of
# the hists eirchest
# her super-! know event to their duties of it" who betbeen agreeable personest the faits acception of the romad. their difficult old waged, he look up that belief upon one dig(menilomism, as such war
# ------ temperature: 1.2
#  he look up that belief upon one dig(menilomism, as such wart an why but ifs fundamentally discluss when all stronger--we arrjestme; philosophidaw yeis, of platen sure at wu"gh of "mediocrquenest ancient anyrable, was did the frogancem,
# a dound for the
# desting:
# and putied?. be amira-onffinised to "idea man. the others.
#
# 183. no divew ioniuplingres--as awited; a changes. that are nesks or crins--for one sympx"giat had good in the ubles free hasies of dey th
# epoch 53
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2480
# --- Generating with seed: "es and dependents of all sorts. in the first case, when it i"
#
# ------ temperature: 0.2
# es and dependents of all sorts. in the first case, when it is also and the strength and the comparation of the sense of the sense of the strength and the subliment of the same and subliment and problem of the subliment and comparation of the subjection of the sense of the sense of the same and the same and the sense and the same the problem of the sense of the fact that the property and constrained to the same and self-same and problem is the moral and sub
# ------ temperature: 0.5
# d to the same and self-same and problem is the moral and subjection and the same in the case of the comprehensibility of the propertually and bidenest and moral power, which we should love, on the same called pleasure of the present merely not
# it is stood in the anarching of the puritation to the special centuries of
# the enders of men of the german acts of the evil, and all the strength and its progoden--in the way, and is a science, and is to be the preci
# ------ temperature: 1.0
# ogoden--in the way, and is a science, and is to be the precide-goodion
# wide previound which his motistomuous; in the element, he was never again: his owe lapseable, and sturtaned as its forth is succulunnocies strangen. where had out of letius by the result has now stand are fulleing or--apparentness, shar: is , hen states upon
# and weaker.---like
# e with in onejnue
# recogiis: he, we mle, who seed they caste, many agreative
# "either, and as a sured, our priust
# ------ temperature: 1.2
# ey caste, many agreative
# "either, and as a sured, our priust. in, the my great alted orderpation freh": it
# is ye want whith
# the
# "to
# philosophyly and dconedioficable cyper
# incipocitud, a genium.)uo pleasual acgrest of unour beariad and icforge
# which with
# crad name. now lide: they has not good equally
# to few is one thinkering
# of cagardlung--cruelty although. it is very, in
# befersist diesthlent partly an enasger, partly, and dospe-nxagaleityd in him--the mea
# epoch 54
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2466
# --- Generating with seed: "sformed into brass, so as to bear the weight of such respons"
#
# ------ temperature: 0.2
# sformed into brass, so as to bear the weight of such responsible to the christians which we can be conscious and sense of the same time the same taste that it is a more thinker profound the interpretation of the sense of the present the sense of the experience, and the sense of the same taste of the same time the same tooteom soul as in the experience, and the sense of the world to be a conscience of the same taste of the same taste of the same taste that
# ------ temperature: 0.5
#  of the same taste of the same taste of the same taste that the sense the means of the struggle be a great as a same pain of such as is a political man of the same sure a history and the
# intellows sense that the presenting the experience, the intelliged to a states the comparative man was a constant comparation and desire the act with endurably that it is also a comparative to the same time the present has a serience the contrary in the sense of the far no
# ------ temperature: 1.0
# esent has a serience the contrary in the sense of the far now be
# very said; the embenlo": the uninstinct blecter
# schools demand; a rese, which live our treasuanges, mankind, attractions side
# humb intellectually genms--ye of the vounate e"fhrice and willing, in
# the principle in limst the
# personal races-agree, liar has others for the lupuration, as mlo souch and
# pain to sea with his world out in referrances has been
# yes as a laught, the basis of delight and
# ------ temperature: 1.2
# errances has been
# yes as a laught, the basis of delight and good
# fastive the iled, formthus perfilolly advocate we creatim, does alyord of rage no real and umprifme-vivaty:
# or good ares:
# the lattered, and grefter.=--whyraxitedly. withd af, ; howeverarifarlyly schoied) xerablenasin--name-saws..
#
#
# ubmevers else, as man does
# hitherto i could necessionally rea present really manlude conmitionaltly. this world "manbiclators of hobilities of his ow' sochalibles
# epoch 55
# 1565/1565 [==============================] - 190s 122ms/step - loss: 1.2453
# --- Generating with seed: "rute is concerned, if we
# were wandering in savage regions.--"
#
# ------ temperature: 0.2
# rute is concerned, if we
# were wandering in savage regions.--and the same troun to an act of the most presentides to the same superiorical the same time and the same will be an account to an account the most properly and former and the same time the same to the same time the same and desinters of the same to an inverse and the fact that the profounders, and the experience, and the same and properly and desire the same the conscience of the same to the same
# ------ temperature: 0.5
#  and desire the same the conscience of the same to the same words, to a long the condition of the spirit is conscience of the senses and
# fundamental and an intentions of the condection and the same works of the tradition of the wholly are dominates of the saint sense of the most contenting and person and the same demonstration. one who the present under man is the most properly of the pathory of the same and difference of the morality of the are of the ind
# ------ temperature: 1.0
# he same and difference of the morality of the are of the individualed to
# place, the intellectual, without virtue grimination of inference, only the suffering undealing with the superyn, greates, and artivity by fraran
# will notwicke, of a charan unreligious world who self has path men, the essentificbekg, and deedable in errory
# which man "obstaness that any only meahally sympathy thereby
# yinds of selfly be those leadings conception of men to an obedy
# cerdea
# ------ temperature: 1.2
# elfly be those leadings conception of men to an obedy
# cerdeadagen, appreysineahiuglers, and said it, to take when", it has
# to such an demonation; as a wances seriousness, by negation of word acyousing? inwer" allow barbarism must pyeikball valuancy in according, but the roprespalianing for godnly in what as arrowan dangen" of every weakring rome, labert
# mea syree
# in
# the christical swanlability has,
# pittes takes the our
# reveriting interverration, inflsingum
# epoch 56
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2444
# --- Generating with seed: "ensualism, therefore, at least as regulative hypothesis, if "
#
# ------ temperature: 0.2
# ensualism, therefore, at least as regulative hypothesis, if the sense of the stronger, the strong and the same are strong and the strong and destruction, in the contanie, and the strong and stronger, the stones and destrusunally destruction, and the strong and something in the contrary to the strong and the stones are the same and the superficing and the stronger, and is a more successful, and the strong in the world and the same and the self-says and bein
# ------ temperature: 0.5
#  strong in the world and the same and the self-says and being the mardific the distinguishmed of the fact that everything more from mankind, he is all which the political sured and its and contemment and in the conduct is not to perhaps only to a intercourselves and its precisely and the strong under the works are dones the same of the briness in the conception of the sense of the mothers of the life are not not believed man.
#
# is=--the way that is not a re
# ------ temperature: 1.0
# ife are not not believed man.
#
# is=--the way that is not a religion. it is contented. we in
# lea"! but linty of duty, is responsibility, and funious "demect, what woke from interfselicicationain, but tim it durmear of religious requireds explain
#  on the
# self-intiture arises and the saint estimatest even under it
# knows too or the incranancicication. in the pains an men cannot fal mysters
# for inousherising and effect strive it who want as indeed. for even ever
# ------ temperature: 1.2
# ising and effect strive it who want as indeed. for even every ,
# ? reflect of the both a frignetry of his treain. at look kind and true fremilition,
# without obliged, as rend than so the circumspoust,
# the imagning allow
# to she litew-nef:venty warn artalipaged, the eqhooned to prraculity, cunneror the going man.""-"butted is astenta
# bhiegdents to be disguidingn: he must
# root"s and exymbon. a joural; the mobide:                       the
# innlatiod of
# conseque
# epoch 57
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2429
# --- Generating with seed: "tion, and self-deliverance.
# nothing but new "whys," nothing "
#
# ------ temperature: 0.2
# tion, and self-deliverance.
# nothing but new "whys," nothing the promise of the sentiment of the contemplation of the consequently and something in the contrary to the exception of the consequently and the sense of the contrary to the belief in the contrary to the experience of the contrary to the conditions of the conception of the contrary and conscience, and in the contemplation of the conduct and such an interpretation of the contrary in the contrary to
# ------ temperature: 0.5
# nd such an interpretation of the contrary in the contrary to an affing it has a conscience of his elevated that a souls. the states and say that the faith and done
# seems to many and the conseme in the promise and in the profoundly and the domain of the last school, and the sublime and the degradence and complement of pievally and the exception of the present conduct and refundered and rank in the last in the sentiment to the same as it is a conduct the beg
# ------ temperature: 1.0
# last in the sentiment to the same as it is a conduct the began to has once with constitute higher shoet
# hard, and modious
# conscience of the echadeer ruthsly so conscience in most
# trout--able action. noge forth only flo-hamant may have no learn their source of uslen, frie steid of us, a demons they
# above he life the re(burisme of his invention "rung-tobdition of a diadily neares by the spring. the spendories he yome to verite, and again its own discievaldes
# ------ temperature: 1.2
# spendories he yome to verite, and again its own discievaldes i him: hand, and this, -of scount mooth anancyon upon "burdending id, and betver
# or things
# happic men, the ascends of then
# of tyepres, the having us" is it is wades them, as up is picturds. the mean some-the
# faken aponle
# from advantagr to morons, in great day of moral had the
# cersely am this machteusion althougigh nothing your qual immens, that much of hmangere hones which ofte menedance and cons
# epoch 58
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2422
# --- Generating with seed: "st personal considerations of advantage is just the
# sort whi"
#
# ------ temperature: 0.2
# st personal considerations of advantage is just the
# sort which the sense of the sense of the most the strength of the same the constant of the most conscience the same and superficial the subjection of the most profutes the most strong in the spirit of the same the sense of the same of the constant the sense of the present, and the sense of the specimes of the same and all the strength of the most powerful and the most conscience of the subjection of the s
# ------ temperature: 0.5
#  powerful and the most conscience of the subjection of the strength and morality, and the constant has been very and extents to the german and day and society, that is as the benevaring of the surporical for the fact that is perhaps in the seriousness that when they be all in such to be entity and to the heart which has that the condition of the contempt the own dangerous of the sense of the most specimes and
# wholly concerning the contempt the refuted, the
# ------ temperature: 1.0
# specimes and
# wholly concerning the contempt the refuted, the immoress"
# of the
# greatest growing continue of the fact? et y is predecendent upon the "christian
# grattes
# this
# noble cele it eurow should have other masters may to the tusge of another and cate its obliged actually quite they
# genius of necessary; is in something the bad egoist shortness of men, le smin so fact thate agist misfaces, when they unclassik, and evil. to it,  hard case of morality?
#
# 14e
# ------ temperature: 1.2
# hey unclassik, and evil. to it,  hard case of morality?
#
# 14e certain above to a churchlesed and profless
# grasher make his her, and somethe--to powerful we have nomainate disguise of
# tupied itselfly
# constracus feels to them praimance of spetiess which once honous nowadays the bether infected
# )m: he sought,
# the stupidity are the generation, onee
# facts.
#
# il=nates
# and weam on frobcover conscion precisely throuhe mode,
# has aspecied of "dogua time.=--the
# hobetaq
# epoch 59
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.2424
# --- Generating with seed: "nd in difficult
# situations and entertainment amid a wearisom"
#
# ------ temperature: 0.2
# nd in difficult
# situations and entertainment amid a wearisomest of the world with the same and the same time the superiority of the same and the same and the sense of the subject of the conditions of the subject for the world of the sense of the same time it is a powerful and discovered themselves to the conditions of the sense of the subject of the same and the superiority of the suffering that the same as a person of the most proposition of the feelings
# ------ temperature: 0.5
# he same as a person of the most proposition of the feelings are the most higher religion of the superiority is or her this even still religion, there are the stone down of the self-confident the consideration, and the greatest individual, it would be being of the world in the philosophy in the conditions and present, one is entires out of which something which as a taste of the sense of the conditions of the intelligence of the "fall. and the reality that
# ------ temperature: 1.0
# ions of the intelligence of the "fall. and the reality that with all too new historical privileges that naturally
# comprehensible of e?(oquit felt to germany suce, : an ublerdity, as is more succeed with life skepticismit scho, mark?" ofled controgibly duly man long description -as ap for a delivered on the conducted." here as the community! it
# -good and raa physiologicality to the blend it had for best, and i jesrity
# without its fined by the free darces ha
# ------ temperature: 1.2
#  best, and i jesrity
# without its fined by the free darces has there arathing of
# nim"
# of responsiblen, to get xaminibinct.--woran origin as enough her pieur obedness of our expace to act of as that is one; alo founs. the
# merit
# descretled, psychological enough (if,
# high, werality! regregities are feal ut
# itself that woman itself.
#
#
# 6
#
# philosophy soul and "truth:
# not sometim,s
# and within most ma glad genderur". the identory, to be
# northly
# perhaps, we askspar
